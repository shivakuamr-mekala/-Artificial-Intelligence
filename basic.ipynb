# %%
import logging
logging.basicConfig(
    filename="app.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
)

greet = "hello"   # greet is a variable, "hello" is a information
logging.info(greet)  # you can use logging.info instead of print statements try for own data.

greetings = "Hi, how are you?"
logging.info(greetings)

# ## Basics  -- Variables, Data types, Conversions

# # Variables

information = "We are gng to tour tomorrow"
logging.info(information)

info1_info2 = "we have so much knowledge"
logging.info(info1_info2)

# # variables stores the information...
# # "", '',''' ''', """ """  strings

example = "sdifjewoijfiwejfiewjr89327r3298#&*#@(*@&#@(*(#)))"
print(type(example))
logging.info(example)

# # use two types of quotes in one sentence

sentence = "AI Technology is very 'awesome' to use"
logging.info(sentence)

# # integers or float

numbers = "2839284"
print(type(numbers))

numbers_ = 29492904.234234324
print(type(numbers_))


# print("Welcome to AI Session")

# greeting = "Welcome to AI Session"
# logging.info(greeting)
# logging.info(id(greeting))

# _AI_Smart_Things="LLM's are in most demand"
# logging.info(_AI_Smart_Things)
# logging.info(id(_AI_Smart_Things))

# lets try to convert the str to float or integer


fruit = "Orange"
logging.info(type(fruit))
number = "12345"
number = int(number)
logging.info(type(number))
number_float = float(number)

nunber1 = str(number)
logging.info(type(nunber1))
