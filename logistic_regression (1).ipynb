# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import seaborn as sns

# %%
df = pd.read_csv("claimants (1).csv")

# %%
df
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0           5         0     0.0       1.0       0.0    50.0  34.940
# 1           3         1     1.0       0.0       0.0    18.0   0.891
# 2          66         1     0.0       1.0       0.0     5.0   0.330
# 3          70         0     0.0       1.0       1.0    31.0   0.037
# 4          96         1     0.0       1.0       0.0    30.0   0.038
# ...       ...       ...     ...       ...       ...     ...     ...
# 1335    34100         1     0.0       1.0       0.0     NaN   0.576
# 1336    34110         0     1.0       1.0       0.0    46.0   3.705
# 1337    34113         1     1.0       1.0       0.0    39.0   0.099
# 1338    34145         0     1.0       0.0       0.0     8.0   3.177
# 1339    34153         1     1.0       1.0       0.0    30.0   0.688
#
# [1340 rows x 7 columns]

# %%
df.head()
# Out:
#    CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0        5         0     0.0       1.0       0.0    50.0  34.940
# 1        3         1     1.0       0.0       0.0    18.0   0.891
# 2       66         1     0.0       1.0       0.0     5.0   0.330
# 3       70         0     0.0       1.0       1.0    31.0   0.037
# 4       96         1     0.0       1.0       0.0    30.0   0.038

# %%
df.tail()
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE   LOSS
# 1335    34100         1     0.0       1.0       0.0     NaN  0.576
# 1336    34110         0     1.0       1.0       0.0    46.0  3.705
# 1337    34113         1     1.0       1.0       0.0    39.0  0.099
# 1338    34145         0     1.0       0.0       0.0     8.0  3.177
# 1339    34153         1     1.0       1.0       0.0    30.0  0.688

# %%
df.sample(5)
# Out:
#      CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 784    10040         1     1.0       1.0       0.0     NaN   3.975
# 192     4707         1     1.0       1.0       0.0     6.0   0.000
# 822    10354         0     1.0       1.0       0.0    44.0   6.400
# 410      479         0     1.0       1.0       0.0    45.0  49.015
# 105     1304         0     0.0       1.0       0.0    43.0   4.485

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CASENUM   1340 non-null   int64
#  1   ATTORNEY  1340 non-null   int64
#  2   CLMSEX    1328 non-null   float64
#  3   CLMINSUR  1299 non-null   float64
#  4   SEATBELT  1292 non-null   float64
#  5   CLMAGE    1151 non-null   float64
#  6   LOSS      1340 non-null   float64
# dtypes: float64(5), int64(2)
# memory usage: 73.4 KB

# %%
df.shape
# Out:
# (1340, 7)

# %%
df.describe()
# Out:
#             CASENUM     ATTORNEY       CLMSEX     CLMINSUR     SEATBELT  \
# count   1340.000000  1340.000000  1328.000000  1299.000000  1292.000000
# mean   11202.001493     0.488806     0.558735     0.907621     0.017028
# std     9512.750796     0.500061     0.496725     0.289671     0.129425
# min        0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     4177.000000     0.000000     0.000000     1.000000     0.000000
# 50%     8756.500000     0.000000     1.000000     1.000000     0.000000
# 75%    15702.500000     1.000000     1.000000     1.000000     0.000000
# max    34153.000000     1.000000     1.000000     1.000000     1.000000
#
#             CLMAGE         LOSS
# count  1151.000000  1340.000000
# mean     28.414422     3.806307
# std      20.304451    10.636903
# min       0.000000     0.000000
# 25%       9.000000     0.400000
# 50%      30.000000     1.069500
# 75%      43.000000     3.781500
# max      95.000000   173.604000

# %%
df.isna().sum()
# Out:
# CASENUM       0
# ATTORNEY      0
# CLMSEX       12
# CLMINSUR     41
# SEATBELT     48
# CLMAGE      189
# LOSS          0
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0           5         0     0.0       1.0       0.0    50.0  34.940
# 1           3         1     1.0       0.0       0.0    18.0   0.891
# 2          66         1     0.0       1.0       0.0     5.0   0.330
# 3          70         0     0.0       1.0       1.0    31.0   0.037
# 4          96         1     0.0       1.0       0.0    30.0   0.038
# ...       ...       ...     ...       ...       ...     ...     ...
# 1334    34104         1     1.0       1.0       0.0    16.0   0.060
# 1336    34110         0     1.0       1.0       0.0    46.0   3.705
# 1337    34113         1     1.0       1.0       0.0    39.0   0.099
# 1338    34145         0     1.0       0.0       0.0     8.0   3.177
# 1339    34153         1     1.0       1.0       0.0    30.0   0.688
#
# [1096 rows x 7 columns]

# %%
df.drop(["CASENUM"],axis=1,inplace=True)
# Out:
# <ipython-input-13-2d60fb21ba59>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(["CASENUM"],axis=1,inplace=True)

# %%
df
# Out:
#       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0            0     0.0       1.0       0.0    50.0  34.940
# 1            1     1.0       0.0       0.0    18.0   0.891
# 2            1     0.0       1.0       0.0     5.0   0.330
# 3            0     0.0       1.0       1.0    31.0   0.037
# 4            1     0.0       1.0       0.0    30.0   0.038
# ...        ...     ...       ...       ...     ...     ...
# 1334         1     1.0       1.0       0.0    16.0   0.060
# 1336         0     1.0       1.0       0.0    46.0   3.705
# 1337         1     1.0       1.0       0.0    39.0   0.099
# 1338         0     1.0       0.0       0.0     8.0   3.177
# 1339         1     1.0       1.0       0.0    30.0   0.688
#
# [1096 rows x 6 columns]

# %%
df.corr()
# Out:
#           ATTORNEY    CLMSEX  CLMINSUR  SEATBELT    CLMAGE      LOSS
# ATTORNEY  1.000000  0.097475  0.084609 -0.060795  0.001132 -0.225769
# CLMSEX    0.097475  1.000000  0.058164 -0.017814 -0.017942 -0.029742
# CLMINSUR  0.084609  0.058164  1.000000  0.021217  0.048166  0.019502
# SEATBELT -0.060795 -0.017814  0.021217  1.000000 -0.028343  0.131182
# CLMAGE    0.001132 -0.017942  0.048166 -0.028343  1.000000  0.065513
# LOSS     -0.225769 -0.029742  0.019502  0.131182  0.065513  1.000000

# %%
df.columns
# Out:
# Index(['ATTORNEY', 'CLMSEX', 'CLMINSUR', 'SEATBELT', 'CLMAGE', 'LOSS'], dtype='object')

# %%
X = df.drop(["ATTORNEY"],axis=1)
y = df["ATTORNEY"]

# %%
lr = LogisticRegression()
lr.fit(X,y)
# Out:
# LogisticRegression()

# %%
predictions = lr.predict(X)
pred_prob = lr.predict_proba(X)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y,predictions)
# Out:
# 0.708029197080292

# %%
df["predictions"] = predictions
# Out:
# <ipython-input-21-8852d362a5fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["predictions"] = predictions

# %%
df
# Out:
#       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS  predictions
# 0            0     0.0       1.0       0.0    50.0  34.940            0
# 1            1     1.0       0.0       0.0    18.0   0.891            1
# 2            1     0.0       1.0       0.0     5.0   0.330            1
# 3            0     0.0       1.0       1.0    31.0   0.037            0
# 4            1     0.0       1.0       0.0    30.0   0.038            1
# ...        ...     ...       ...       ...     ...     ...          ...
# 1334         1     1.0       1.0       0.0    16.0   0.060            1
# 1336         0     1.0       1.0       0.0    46.0   3.705            0
# 1337         1     1.0       1.0       0.0    39.0   0.099            1
# 1338         0     1.0       0.0       0.0     8.0   3.177            0
# 1339         1     1.0       1.0       0.0    30.0   0.688            1
#
# [1096 rows x 7 columns]

# %%
class_0_prob = pred_prob[:,0]

# %%
class_1_prob = pred_prob[:,1]

# %%
df["prob_class_1"] =  class_1_prob
df["prob_class_0"] =  class_0_prob
# Out:
# <ipython-input-25-28bed08d7c60>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["prob_class_1"] =  class_1_prob
# <ipython-input-25-28bed08d7c60>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["prob_class_0"] =  class_0_prob

# %%
df.columns
# Out:
# Index(['ATTORNEY', 'CLMSEX', 'CLMINSUR', 'SEATBELT', 'CLMAGE', 'LOSS',
#        'predictions', 'prob_class_1', 'prob_class_0'],
#       dtype='object')

# %%
cols = ['ATTORNEY','predictions','prob_class_1','prob_class_0']
data = df[cols]

# %%
data
# Out:
#       ATTORNEY  predictions  prob_class_1  prob_class_0
# 0            0            0      0.000003      0.999997
# 1            1            1      0.507168      0.492832
# 2            1            1      0.575164      0.424836
# 3            0            0      0.497716      0.502284
# 4            1            1      0.640754      0.359246
# ...        ...          ...           ...           ...
# 1334         1            1      0.712081      0.287919
# 1336         0            0      0.425825      0.574175
# 1337         1            1      0.739029      0.260971
# 1338         0            0      0.285954      0.714046
# 1339         1            1      0.680431      0.319569
#
# [1096 rows x 4 columns]

# %%
data = sns.load_dataset("iris")

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
data.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 77            6.7          3.0           5.0          1.7  versicolor
# 134           6.1          2.6           5.6          1.4   virginica
# 63            6.1          2.9           4.7          1.4  versicolor
# 82            5.8          2.7           3.9          1.2  versicolor
# 39            5.1          3.4           1.5          0.2      setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data[data.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 142           5.8          2.7           5.1          1.9  virginica

# %%
data = data.drop_duplicates()

# %%
data.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
data["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
data["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     49
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data["species"] = LabelEncoder.fit_transform(data,data["species"])

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [149 rows x 5 columns]

# %%
data["species"].unique()
# Out:
# array([0, 1, 2])

# %%
data["species"].value_counts()
# Out:
# species
# 0    50
# 1    50
# 2    49
# Name: count, dtype: int64

# %%
model = LogisticRegression()
X = data.drop(["species"],axis=1)
y = data["species"]
model.fit(X,y)
# Out:
# LogisticRegression()

# %%
predictions = model.predict(X)
pred_prob = model.predict_proba(X)

# %%
accuracy_score(y,predictions)
# Out:
# 0.9731543624161074

# %%
data["predictions"] = predictions

# %%
pred_prob
# Out:
# array([[9.81695908e-01, 1.83040768e-02, 1.55703065e-08],
#        [9.71420500e-01, 2.85794678e-02, 3.20861408e-08],
#        [9.85292083e-01, 1.47079043e-02, 1.31131026e-08],
#        [9.76029547e-01, 2.39704107e-02, 4.18892899e-08],
#        [9.85306805e-01, 1.46931826e-02, 1.28788426e-08],
#        [9.70474621e-01, 2.95252991e-02, 7.95105034e-08],
#        [9.86765849e-01, 1.32341296e-02, 2.11495082e-08],
#        [9.76245335e-01, 2.37546352e-02, 2.96236537e-08],
#        [9.79551887e-01, 2.04480812e-02, 3.21340985e-08],
#        [9.68842814e-01, 3.11571522e-02, 3.37791733e-08],
#        [9.76459224e-01, 2.35407551e-02, 2.09494864e-08],
#        [9.75232039e-01, 2.47679147e-02, 4.66586589e-08],
#        [9.74273083e-01, 2.57268942e-02, 2.28747138e-08],
#        [9.91847569e-01, 8.15242719e-03, 4.11538961e-09],
#        [9.88219272e-01, 1.17807244e-02, 3.13034286e-09],
#        [9.86842478e-01, 1.31575081e-02, 1.41291374e-08],
# ...

# %%
class_setosa_0 = pred_prob[:,0]
class_versicolor_1 = pred_prob[:,1]
class_viriginica_2 = pred_prob[:,2]

# %%
data["class_setosa_0"] = class_setosa_0
data["class_versicolor_1"] = class_versicolor_1
data["class_viriginica_2"] = class_viriginica_2

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species  \
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
#      predictions  class_setosa_0  class_versicolor_1  class_viriginica_2
# 0              0        0.981696            0.018304        1.557031e-08
# ...
